# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# define url
url = f"http://api.openweathermap.org/data/2.5/weather?appid=a879eb97b76ef7f738ef0b6c296f3e7d&units=imperial&q="
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# lists for dataframe
city_two=[]
cloudiness=[]
dates=[]
humidities=[]
lats=[]
lngs=[]
max_temps=[]
wind_speeds=[]
countries=[]

#intial count
count_one=0
set_one=1

# loop cities
for city in cities:
    try:
        print(url + city.replace(" ",""))
        response = requests.get(url + city.replace(" ","")).json()
        cloudiness.append(response["clouds"]["all"])
        countries.append(response['sys']['country'])
        dates.append(response["dt"])
        humidities.append(response["main"]["humidity"])
        lats.append(response["coord"]["lat"])
        lngs.append(response["coord"]["lon"])
        max_temps.append(response["main"]["temp_max"])
        wind_speeds.append(response["wind"]["speed"])
        if count_one>48:
            count_one=1
            city_two.append(city)
        else:
            count_one+=1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception as e:
        print(e)
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=a879eb97b76ef7f738ef0b6c296f3e7d&units=imperial&q=portelizabeth
# 'clouds'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=a879eb97b76ef7f738ef0b6c296f3e7d&units=imperial&q=hamilton
# Processing Record 1 of Set 1 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=a879eb97b76ef7f738ef0b6c296f3e7d&units=imperial&q=kasongo-lunda
# Processing Record 2 of Set 1 | kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?appid=a879eb97b76ef7f738ef0b6c296f3e7d&units=imperial&q=puntaarenas
# 'clouds'
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=a879eb97b76ef7f738ef0b6c296f3e7d&units=imperial&q=kapaa
# Processing Record 3 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=a879eb97b76ef7f738ef0b6c296f3e7d&units=imperial&q=hithadhoo
# Processing Record 4 of Set 1 | hithadhoo
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weatherDict={
            "City":city_two,
            "Cloudiness":cloudiness,
            "Country":countries,
            "Date":dates,
            "Humidity":humidities,
            "Lat":lats,
            "Lng":lngs,
            "Max Temp":max_temps,
            "Wind Speed":wind_speeds}

# %%
weatherDict_dataframe = pd.DataFrame(weatherDict)
weatherDict_dataframe.count()
# Out:
# City          463
# Cloudiness    463
# Country       463
# Date          463
# Humidity      463
# Lat           463
# Lng           463
# Max Temp      463
# Wind Speed    463
# dtype: int64

# %%
weatherDict_dataframe.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       hamilton          90      CA  1570387930        82  43.26  -79.87
# 1  kasongo-lunda          58      CD  1570387635        74  -6.48   16.82
# 2          kapaa           1      US  1570388063        83  22.08 -159.32
# 3      hithadhoo         100      MV  1570388064        74  -0.60   73.08
# 4       katsuura          40      JP  1570388064        77  33.93  134.50
#
#    Max Temp  Wind Speed
# 0     68.00       12.75
# 1     75.08        0.78
# 2     78.80        2.15
# 3     82.37       11.83
# 4     64.40        5.82

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weatherDict_dataframe["Lat"],weatherDict_dataframe["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temprature (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temprature (F)")
plt.grid(b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weatherDict_dataframe["Lat"],weatherDict_dataframe["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weatherDict_dataframe["Lat"],weatherDict_dataframe["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weatherDict_dataframe["Lat"],weatherDict_dataframe["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.show()
